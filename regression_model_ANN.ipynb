# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/gdrive/MyDrive/Deep learning/Admission_Predict_Ver1.1.csv')

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df.shape
# Out:
# (500, 9)

# %% [markdown]
# we will drop sr no col and use 7 features as inputs to the neuron, chance of admit will be the label

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         500 non-null    int64
#  1   GRE Score          500 non-null    int64
#  2   TOEFL Score        500 non-null    int64
#  3   University Rating  500 non-null    int64
#  4   SOP                500 non-null    float64
#  5   LOR                500 non-null    float64
#  6   CGPA               500 non-null    float64
#  7   Research           500 non-null    int64
#  8   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 35.3 KB

# %% [markdown]
# 7 input features and 7 hidden layers means 7x7+7 trainable params in layer 1,
# in layers 2 there are:= 7x1+1 params , total params = 64 parameters

# %%
df.drop(columns= {'Serial No.'}, inplace=True)

# %%
df.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0        337          118                  4  4.5   4.5  9.65         1
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1
# 3        322          110                  3  3.5   2.5  8.67         1
# 4        314          103                  2  2.0   3.0  8.21         0
#
#    Chance of Admit
# 0              0.92
# 1              0.76
# 2              0.72
# 3              0.80
# 4              0.65

# %%
X = df.iloc[:,0:-1]
y = df.iloc[:,-1]

# %%
X
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 495        332          108                  5  4.5   4.0  9.02         1
# 496        337          117                  5  5.0   5.0  9.87         1
# 497        330          120                  5  4.5   5.0  9.56         1
# 498        312          103                  4  4.0   5.0  8.43         0
# 499        327          113                  4  4.5   4.5  9.04         0
#
# [500 rows x 7 columns]

# %%
y
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
#        ...
# 495    0.87
# 496    0.96
# 497    0.93
# 498    0.73
# 499    0.84
# Name: Chance of Admit , Length: 500, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 238        310          104                  3  2.0   3.5  8.37         0
# 438        318          110                  1  2.5   3.5  8.54         1
# 475        300          101                  3  3.5   2.5  7.88         0
# 58         300           99                  1  3.0   2.0  6.80         1
# 380        322          104                  3  3.5   4.0  8.84         1
# ..         ...          ...                ...  ...   ...   ...       ...
# 255        307          110                  4  4.0   4.5  8.37         0
# 72         321          111                  5  5.0   5.0  9.45         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 235        326          111                  5  4.5   4.0  9.23         1
# 37         300          105                  1  1.0   2.0  7.80         0
#
# [400 rows x 7 columns]

# %%
X_test
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 304        313          106                  2  2.5   2.0  8.43         0
# 340        312          107                  3  3.0   3.0  8.46         1
# 47         339          119                  5  4.5   4.0  9.70         0
# 67         316          107                  2  3.5   3.5  8.64         1
# 479        325          110                  4  4.5   4.0  8.96         1
# ..         ...          ...                ...  ...   ...   ...       ...
# 11         327          111                  4  4.0   4.5  9.00         1
# 192        322          114                  5  4.5   4.0  8.94         1
# 92         298           98                  2  4.0   3.0  8.03         0
# 221        316          110                  3  3.5   4.0  8.56         0
# 110        305          108                  5  3.0   3.0  8.48         0
#
# [100 rows x 7 columns]

# %%
y_train
# Out:
# 238    0.70
# 438    0.67
# 475    0.59
# 58     0.36
# 380    0.78
#        ...
# 255    0.79
# 72     0.93
# 396    0.84
# 235    0.88
# 37     0.58
# Name: Chance of Admit , Length: 400, dtype: float64

# %%
y_test
# Out:
# 304    0.62
# 340    0.75
# 47     0.89
# 67     0.57
# 479    0.79
#        ...
# 11     0.84
# 192    0.86
# 92     0.34
# 221    0.75
# 110    0.61
# Name: Chance of Admit , Length: 100, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[0.4       , 0.42857143, 0.5       , ..., 0.57142857, 0.50320513,
#         0.        ],
#        [0.56      , 0.64285714, 0.        , ..., 0.57142857, 0.55769231,
#         1.        ],
#        [0.2       , 0.32142857, 0.5       , ..., 0.28571429, 0.34615385,
#         0.        ],
#        ...,
#        [0.7       , 0.53571429, 0.5       , ..., 0.57142857, 0.74038462,
#         1.        ],
#        [0.72      , 0.67857143, 1.        , ..., 0.71428571, 0.77884615,
#         1.        ],
#        [0.2       , 0.46428571, 0.        , ..., 0.14285714, 0.32051282,
#         0.        ]])

# %%
import tensorflow
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %%
#now lets make the beural net
model = Sequential()

model.add(Dense(7,activation='relu',input_dim=7))
model.add(Dense(1,activation='linear'))     #as it is a regression problem

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_2 (Dense)             (None, 7)                 56
#
#  dense_3 (Dense)             (None, 1)                 8
#
# ...
# Total params: 64 (256.00 Byte)
# Trainable params: 64 (256.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='mean_squared_error',optimizer='Adam')

# %%
history = model.fit(X_train_scaled, y_train, epochs=100, validation_split=0.2)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 19ms/step - loss: 0.8799 - val_loss: 0.7948
# Epoch 2/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6317 - val_loss: 0.5600
# Epoch 3/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4399 - val_loss: 0.3790
# Epoch 4/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2914 - val_loss: 0.2478
# Epoch 5/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1870 - val_loss: 0.1569
# Epoch 6/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1171 - val_loss: 0.0976
# Epoch 7/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0721 - val_loss: 0.0626
# Epoch 8/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0465 - val_loss: 0.0436
# Epoch 9/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0334 - val_loss: 0.0345
# Epoch 10/100
# ...

# %%
y_pred = model.predict(X_test_scaled)
# Out:
# 4/4 [==============================] - 0s 3ms/step

# %%
y_pred
# Out:
# array([[0.66407037],
#        [0.71298873],
#        [0.8874996 ],
#        [0.65519375],
#        [0.8457808 ],
#        [0.56021845],
#        [0.65869   ],
#        [0.6938944 ],
#        [0.7597471 ],
#        [0.61779916],
#        [0.6677957 ],
#        [0.5120736 ],
#        [0.75971663],
#        [0.7668177 ],
#        [0.74107546],
#        [0.93881273],
#        [0.66358626],
#        [0.7097738 ],
#        [0.9244933 ],
#        [0.5690942 ],
#        [0.5006934 ],
#        [0.8183928 ],
#        [0.8143014 ],
#        [0.68748975],
#        [0.765717  ],
#        [0.63256824],
#        [0.8672515 ],
#        [0.68280774],
#        [0.8486062 ],
#        [0.6699781 ],
#        [0.66076595],
#        [0.7696373 ],
#        [0.60047513],
#        [0.89697796],
#        [0.52155805],
#        [0.7703781 ],
#        [0.60263515],
#        [0.6085143 ],
#        [0.6682391 ],
#        [0.87634933],
#        [0.5221137 ],
#        [0.7299618 ],
#        [0.744983  ],
# ...

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.6602614453804189
